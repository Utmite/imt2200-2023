# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="attachment:logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2023-2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>
# ---

# %% [markdown]
# # <h1><center>Clase 17: Exploración de Datos</center></h1>
#
# Este notebook continua el trabajo anterior, con el objetivo que los estudiantes del curso aprendan diferentes comandos y técnicas en Python y, en particular, en Seaborn, para la exploración de datos.

# %% [markdown]
# ## 1. Datos a analizar
#
# El archivo `datos_clase17.csv` posee un conjunto de datos grande creado en forma sintética para este ejercicio.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Lectura de los datos

# %%
dfe = pd.read_csv('datos_clase17.csv')
dfe.head()
# Out:
#    Valores  Category1 Category2
# 0      6.4         15         P
# 1      5.1         15         P
# 2      4.8         15         P
# 3      5.2         15         P
# 4      5.3         15         P

# %% [markdown]
# ## 2. Histogramas

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

sns.histplot(data=dfe, x='Valores', bins = 20, kde=True);
ax.set_ylabel('Cuentas')
# Out:
# Text(0, 0.5, 'Cuentas')

# %%
sns.set_style("ticks")
sns.set_context("talk")

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

sns.histplot(data=dfe, x='Valores', bins = 20, kde=True);
ax.set_ylabel('Cuentas')
# Out:
# Text(0, 0.5, 'Cuentas')

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

sns.kdeplot(data=dfe,x='Valores', ax=ax, gridsize=20);
ax.set_ylabel('KDE')
# Out:
# Text(0, 0.5, 'KDE')

# %% [markdown]
# **Notas:** Revise la documentación de `seaborn.histplot`y verifique cómo cambian sus gráficos al cmabiar los argumentos:`bins`,`stat`,`kde`y otros que llamen su atención.

# %%
mu = dfe['Valores'].mean()
sigma = dfe['Valores'].std()

samples = np.random.normal(mu, sigma, len(dfe))
dfe['Valores2'] = samples
dfe
# Out:
#          Valores  Category1 Category2  Valores2
# 0            6.4         15         P  5.516992
# 1            5.1         15         P  5.690124
# 2            4.8         15         P  4.929291
# 3            5.2         15         P  7.068128
# 4            5.3         15         P  5.969088
# ...          ...        ...       ...       ...
# 2959235      7.0          8         P  6.417330
# 2959236      6.5          8         P  5.986286
# 2959237      5.0          8         P  6.120742
# 2959238      6.6          8         P  6.459734
# 2959239      6.6          8         P  5.888162
#
# [2959240 rows x 4 columns]

# %%
sns.set_style("ticks")
sns.set_context("talk")

fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

mu = dfe.Valores.mean()
sigma = dfe.Valores.std()

print(sigma,mu)

sns.histplot(data=dfe,x='Valores',ax=ax1,stat='density',bins=20,);
sns.histplot(data=dfe,x='Valores2',ax=ax2,stat='density',bins=20,color='g',alpha=0.5);
ax2.set_xlabel('Valores')

ax1.set_ylabel('Cuentas')
ax2.set_ylabel('Cuentas')

ax1.text(1.5,0.6,r'$\mu$ = 6.02',color='tab:blue')
ax1.text(1.5,0.55,r'$\sigma$ = 0.76',color='tab:blue')

ax2.text(1.5,0.6,r'$\mu$ = 6.02',color='tab:green')
ax2.text(1.5,0.55,r'$\sigma$ = 0.76',color='tab:green')

for ax in [ax1,ax2]:
    ax.set_xlim(1,9)
    ax.set_ylim(0,0.7)
# Out:
# 0.7594427170118232 6.017165150511616

# %% [markdown]
# ## 3. Boxplot

# %%
dfe['Valores'].describe()
# Out:
# count    2.959240e+06
# mean     6.017165e+00
# std      7.594427e-01
# min      1.100000e+00
# 25%      5.600000e+00
# 50%      6.200000e+00
# 75%      6.600000e+00
# max      7.000000e+00
# Name: Valores, dtype: float64

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

sns.boxplot(data=dfe,y='Valores',ax=ax)
# Out:
# <Axes: ylabel='Valores'>

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)

sns.violinplot(data=dfe,y='Valores',ax=ax, gridsize=20)
# Out:
# <Axes: ylabel='Valores'>
